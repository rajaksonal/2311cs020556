# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data={
    'Temp':[22,23,20,18,21,19,24,26,23,27,28,30,31,32,34,35,23,15,12,14,24,25,29,34,25,21],
    'Humidity':[56,35,21,56,65,70,45,52,76,78,61,75,49,65,65,70,72,76,80,56,55,79,61,56,50,65],
    'wind speed':[15,10,20,25,10,15,22,25,23,27,28,30,15,10,16,11,19,15,12,14,24,25,29,12,25,21],
    'pressure':[1015,1012,1016,1018,1021,1019,1024,1026,1023,1027,1028,1030,1031,1032,1015,1012,1023,1015,1012,1014,1024,1011,1014,1016,1025,1021]

}

df = pd.DataFrame(data)

# Scatter plot Temp vs Humidity
plt.figure(figsize=(8,6))
plt.scatter(df['Temp'], df['Humidity'], color='blue', label='Temp vs Humidity')
plt.title('Temp vs Humidity')
plt.xlabel('Temp')
plt.ylabel('Humidity')
plt.grid(True)
plt.legend()

# Pairplot without the 'hue' argument
sns.pairplot(df)
plt.show()
